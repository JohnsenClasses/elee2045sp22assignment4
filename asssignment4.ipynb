# %%
import pandas as pd # run, but do not modify this
import numpy as np

# %%
# read the consumption_monthly dataset, using row 1 as the header to produce the following
# Out:
#        YEAR STATE                         TYPE OF PRODUCER  \
# 0      1990    AK            Total Electric Power Industry
# 1      1990    AK            Total Electric Power Industry
# 2      1990    AK            Total Electric Power Industry
# 3      1990    AK            Total Electric Power Industry
# 4      1990    AK            Total Electric Power Industry
# ...     ...   ...                                      ...
# 55880  2020    WY  Electric Generators, Electric Utilities
# 55881  2020    WY  Electric Generators, Electric Utilities
# 55882  2020    WY  Electric Generators, Electric Utilities
# 55883  2020    WY  Electric Generators, Electric Utilities
# 55884  2020    WY  Electric Generators, Electric Utilities
#
#                     ENERGY SOURCE  GENERATION (Megawatthours)
# 0                           Total                   5599506.0
# 1                            Coal                    510573.0
# 2      Hydroelectric Conventional                    974521.0
# ...

# %%
# rename the columns Year, State, Producer, Source, and Energy
# Out:
#        Year State                                 Producer  \
# 0      1990    AK            Total Electric Power Industry
# 1      1990    AK            Total Electric Power Industry
# 2      1990    AK            Total Electric Power Industry
# 3      1990    AK            Total Electric Power Industry
# 4      1990    AK            Total Electric Power Industry
# ...     ...   ...                                      ...
# 55880  2020    WY  Electric Generators, Electric Utilities
# 55881  2020    WY  Electric Generators, Electric Utilities
# 55882  2020    WY  Electric Generators, Electric Utilities
# 55883  2020    WY  Electric Generators, Electric Utilities
# 55884  2020    WY  Electric Generators, Electric Utilities
#
#                            Source      Energy
# 0                           Total   5599506.0
# 1                            Coal    510573.0
# 2      Hydroelectric Conventional    974521.0
# 3                     Natural Gas   3466261.0
# ...

# %%
# Make the last column Gigawatt Hours by dividing by 1000 and rounding

# %%
#show the unique values for Producer
# Out:
# array(['Total Electric Power Industry',
#        'Electric Generators, Electric Utilities',
#        'Combined Heat and Power, Industrial Power',
#        'Combined Heat and Power, Commercial Power',
#        'Electric Generators, Independent Power Producers',
#        'Combined Heat and Power, Electric Power'], dtype=object)

# %%
# keep only the rows that 
    # have the type of producer as total electric power industry, 
    # and the state as georgia, 
    # and remove the "Total" Energy Source
    # and keep years from 2010+
    # and sort the result
# Out:
#        Year State                       Producer  \
# 33710  2010    GA  Total Electric Power Industry
# 33711  2010    GA  Total Electric Power Industry
# 33712  2010    GA  Total Electric Power Industry
# 33713  2010    GA  Total Electric Power Industry
# 33714  2010    GA  Total Electric Power Industry
# ...     ...   ...                            ...
# 54146  2020    GA  Total Electric Power Industry
# 54147  2020    GA  Total Electric Power Industry
# 54148  2020    GA  Total Electric Power Industry
# 54149  2020    GA  Total Electric Power Industry
# 54150  2020    GA  Total Electric Power Industry
#
#                                Source   Energy
# 33710                            Coal  73298.0
# 33711      Hydroelectric Conventional   3322.0
# 33712                     Natural Gas  23884.0
# 33713                         Nuclear  33512.0
# 33714                           Other     18.0
# ...                               ...      ...
# ...

# %%
# Now drop the state and producer, since they are constant
# Out:
# C:\Users\kjjoh\AppData\Local\Temp/ipykernel_22940/1196174868.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["State","Producer"],inplace=True)
#        Year                          Source   Energy
# 33710  2010                            Coal  73298.0
# 33711  2010      Hydroelectric Conventional   3322.0
# 33712  2010                     Natural Gas  23884.0
# 33713  2010                         Nuclear  33512.0
# 33714  2010                           Other     18.0
# ...     ...                             ...      ...
# 54146  2020                           Other     83.0
# 54147  2020                       Petroleum    207.0
# 54148  2020  Solar Thermal and Photovoltaic   3780.0
# 54149  2020                   Other Biomass    322.0
# ...

# %%
# Now, pivot the table to form the below one
# Out:
# Year                               2010     2011     2012     2013     2014  \
# Source
# Natural Gas                     23884.0  26544.0  42539.0  40330.0  40961.0
# Nuclear                         33512.0  32306.0  33942.0  32903.0  32570.0
# Coal                            73298.0  60159.0  40715.0  40233.0  45295.0
# Wood and Wood Derived Fuels      3054.0   3070.0   3107.0   3409.0   3750.0
# Hydroelectric Conventional       3322.0   2705.0   2236.0   3714.0   3064.0
# Solar Thermal and Photovoltaic      NaN      NaN      3.0     14.0    119.0
# Other Biomass                     127.0    119.0    168.0    415.0    413.0
# Petroleum                         641.0    551.0    378.0    275.0    378.0
# Other                              18.0     28.0     56.0     88.0     67.0
# Pumped Storage                   -278.0   -734.0   -838.0   -427.0   -781.0
#
# Year                               2015     2016     2017     2018     2019  \
# Source
# ...

# %%
# Finally, produce a bar chart for each year, but only include the top 3 sources over the time period (Coal, Nuclear, and Natural Gas)
# Out:
# <AxesSubplot:xlabel='Year'>
